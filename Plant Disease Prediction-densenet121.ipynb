# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
    #for filename in filenames:
       # print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cv2
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.models import Model,Sequential, Input, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications import DenseNet121
# Out:
# Using TensorFlow backend.

# %%
disease_types = ['Pepper__bell___Bacterial_spot','Pepper__bell___healthy','Potato___Early_blight','Potato___Late_blight','Potato___healthy','Tomato_Bacterial_spot','Tomato_Early_blight','Tomato_Late_blight','Tomato_Leaf_Mold','Tomato_Septoria_leaf_spot','Tomato_Spider_mites_Two_spotted_spider_mite','Tomato__Target_Spot','Tomato__Tomato_YellowLeaf__Curl_Virus','Tomato__Tomato_mosaic_virus','Tomato_healthy']
data_dir = '../input/plantdisease/PlantVillage/'
train_dir = os.path.join(data_dir)
#test_dir = os.path.join(data_dir, 'test')

# %%
train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])
        
train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])
train.tail()
# Out:
#                                                     File  DiseaseID  \
# 20634  Tomato_healthy/9e43d49b-abbe-4b9b-8566-42586a5...         14
# 20635  Tomato_healthy/7beda862-3964-4839-9d08-b9b3fa2...         14
# 20636  Tomato_healthy/4af1cf6d-1bae-4e58-9168-2f6105a...         14
# 20637  Tomato_healthy/668e811e-7b65-404e-9bc5-6519efb...         14
# 20638  Tomato_healthy/d84eb3b6-3321-4034-9bcc-d2cddb8...         14
#
#          Disease Type
# 20634  Tomato_healthy
# 20635  Tomato_healthy
# 20636  Tomato_healthy
# 20637  Tomato_healthy
# 20638  Tomato_healthy

# %%
# Randomize the order of training set
SEED = 42
train = train.sample(frac=1, random_state=SEED) 
train.index = np.arange(len(train)) # Reset indices
train.head()
# Out:
#                                                 File  DiseaseID  \
# 0  Tomato_healthy/08c1c1e5-bb78-44d5-b46f-a86386c...         14
# 1  Potato___Early_blight/85a38441-6df7-4401-9905-...          2
# 2  Tomato_Septoria_leaf_spot/2139cc43-0f52-4782-9...          9
# 3  Tomato_healthy/ee0dd8c0-8db2-4eff-8e4d-76cb146...         14
# 4  Tomato_Leaf_Mold/b155d628-2bce-404f-bd81-6916f...          8
#
#                 Disease Type
# 0             Tomato_healthy
# 1      Potato___Early_blight
# 2  Tomato_Septoria_leaf_spot
# 3             Tomato_healthy
# 4           Tomato_Leaf_Mold

# %%
# Plot a histogram
plt.hist(train['DiseaseID'])
plt.title('Frequency Histogram of Species')
plt.figure(figsize=(12, 12))
plt.show()

# %%
# Display images for different species
def plot_defects(defect_types, rows, cols):
    fig, ax = plt.subplots(rows, cols, figsize=(12, 12))
    defect_files = train['File'][train['Disease Type'] == defect_types].values
    n = 0
    for i in range(rows):
        for j in range(cols):
            image_path = os.path.join(data_dir, defect_files[n])
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].imshow(cv2.imread(image_path))
            n += 1
# Displays first n images of class from training set
plot_defects('Tomato_Bacterial_spot', 5, 5)

# %%
IMAGE_SIZE = 64

def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))
# Normalize the data
X_Train = X_train / 255.
print('Train Shape: {}'.format(X_Train.shape))
# Out:
# 20639it [01:24, 244.69it/s]
# Train Shape: (20639, 64, 64, 3)

# %%
Y_train = train['DiseaseID'].values
Y_train = to_categorical(Y_train, num_classes=15)

# %%
BATCH_SIZE = 64

# Split the train and validation sets 
X_train, X_val, Y_train, Y_val = train_test_split(X_Train, Y_train, test_size=0.2, random_state=SEED)

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 15))
for i in range(3):
    ax[i].set_axis_off()
    ax[i].imshow(X_train[i])
    ax[i].set_title(disease_types[np.argmax(Y_train[i])])

# %%
EPOCHS = 50
SIZE=64
N_ch=3

# %%
def build_densenet():
    densenet = DenseNet121(weights='imagenet', include_top=False)

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    
    x = densenet(x)
    
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # multi output
    output = Dense(15,activation = 'softmax', name='root')(x)
 

    # model
    model = Model(input,output)
    
    optimizer = Adam(lr=0.002, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=0.0)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()
    
    return model

# %%
model = build_densenet()
annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
# Generates batches of image data with data augmentation
datagen = ImageDataGenerator(rotation_range=360, # Degree range for random rotations
                        width_shift_range=0.2, # Range for random horizontal shifts
                        height_shift_range=0.2, # Range for random vertical shifts
                        zoom_range=0.2, # Range for random zoom
                        horizontal_flip=True, # Randomly flip inputs horizontally
                        vertical_flip=True) # Randomly flip inputs vertically

datagen.fit(X_train)
# Fits the model on batches with real-time data augmentation
hist = model.fit_generator(datagen.flow(X_train, Y_train, batch_size=BATCH_SIZE),
               steps_per_epoch=X_train.shape[0] // BATCH_SIZE,
               epochs=EPOCHS,
               verbose=2,
               callbacks=[annealer, checkpoint],
               validation_data=(X_val, Y_val))
# Out:
# Downloading data from https://github.com/keras-team/keras-applications/releases/download/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 1s 0us/step
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 64, 64, 3)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 3)         84
# _________________________________________________________________
# densenet121 (Model)          multiple                  7037504
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1024)              0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               262400
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# root (Dense)                 (None, 15)                3855
# =================================================================
# Total params: 7,308,963
# Trainable params: 7,222,755
# Non-trainable params: 86,208
# _________________________________________________________________
# Epoch 1/50
#  - 148s - loss: 2.6308 - accuracy: 0.2982 - val_loss: 2.4795 - val_accuracy: 0.2849
#
# Epoch 00001: val_loss improved from inf to 2.47955, saving model to model.h5
# Epoch 2/50
#  - 70s - loss: 1.1150 - accuracy: 0.6486 - val_loss: 2.3409 - val_accuracy: 0.4220
#
# Epoch 00002: val_loss improved from 2.47955 to 2.34088, saving model to model.h5
# Epoch 3/50
#  - 70s - loss: 0.6436 - accuracy: 0.7925 - val_loss: 0.5204 - val_accuracy: 0.8438
#
# Epoch 00003: val_loss improved from 2.34088 to 0.52037, saving model to model.h5
# Epoch 4/50
#  - 71s - loss: 0.4346 - accuracy: 0.8617 - val_loss: 0.4968 - val_accuracy: 0.8471
#
# Epoch 00004: val_loss improved from 0.52037 to 0.49680, saving model to model.h5
# Epoch 5/50
#  - 71s - loss: 0.3408 - accuracy: 0.8936 - val_loss: 0.4694 - val_accuracy: 0.8573
#
# Epoch 00005: val_loss improved from 0.49680 to 0.46939, saving model to model.h5
# Epoch 6/50
#  - 72s - loss: 0.2783 - accuracy: 0.9098 - val_loss: 0.3498 - val_accuracy: 0.8900
#
# Epoch 00006: val_loss improved from 0.46939 to 0.34984, saving model to model.h5
# Epoch 7/50
#  - 72s - loss: 0.2461 - accuracy: 0.9214 - val_loss: 0.6971 - val_accuracy: 0.8069
#
# Epoch 00007: val_loss did not improve from 0.34984
# Epoch 8/50
#  - 73s - loss: 0.2116 - accuracy: 0.9304 - val_loss: 0.6593 - val_accuracy: 0.8047
#
# Epoch 00008: val_loss did not improve from 0.34984
# Epoch 9/50
#  - 73s - loss: 0.1906 - accuracy: 0.9396 - val_loss: 0.8173 - val_accuracy: 0.8295
#
# Epoch 00009: val_loss did not improve from 0.34984
# Epoch 10/50
#  - 71s - loss: 0.1747 - accuracy: 0.9443 - val_loss: 0.8086 - val_accuracy: 0.8207
#
# Epoch 00010: val_loss did not improve from 0.34984
# Epoch 11/50
#  - 70s - loss: 0.1570 - accuracy: 0.9514 - val_loss: 0.3910 - val_accuracy: 0.8866
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
#
# Epoch 00011: val_loss did not improve from 0.34984
# Epoch 12/50
#  - 70s - loss: 0.1241 - accuracy: 0.9617 - val_loss: 0.1421 - val_accuracy: 0.9523
#
# Epoch 00012: val_loss improved from 0.34984 to 0.14214, saving model to model.h5
# Epoch 13/50
#  - 70s - loss: 0.1101 - accuracy: 0.9636 - val_loss: 0.2517 - val_accuracy: 0.9230
#
# Epoch 00013: val_loss did not improve from 0.14214
# Epoch 14/50
#  - 70s - loss: 0.1070 - accuracy: 0.9651 - val_loss: 0.4857 - val_accuracy: 0.8622
#
# Epoch 00014: val_loss did not improve from 0.14214
# Epoch 15/50
#  - 70s - loss: 0.1003 - accuracy: 0.9669 - val_loss: 0.8567 - val_accuracy: 0.8270
#
# Epoch 00015: val_loss did not improve from 0.14214
# Epoch 16/50
#  - 70s - loss: 0.0950 - accuracy: 0.9692 - val_loss: 0.2000 - val_accuracy: 0.9392
#
# Epoch 00016: val_loss did not improve from 0.14214
# Epoch 17/50
#  - 69s - loss: 0.0953 - accuracy: 0.9695 - val_loss: 0.2159 - val_accuracy: 0.9373
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00017: val_loss did not improve from 0.14214
# Epoch 18/50
#  - 69s - loss: 0.0848 - accuracy: 0.9727 - val_loss: 0.4248 - val_accuracy: 0.8871
#
# Epoch 00018: val_loss did not improve from 0.14214
# Epoch 19/50
#  - 70s - loss: 0.0886 - accuracy: 0.9706 - val_loss: 0.1027 - val_accuracy: 0.9668
#
# Epoch 00019: val_loss improved from 0.14214 to 0.10274, saving model to model.h5
# Epoch 20/50
#  - 69s - loss: 0.0856 - accuracy: 0.9718 - val_loss: 0.1139 - val_accuracy: 0.9639
#
# Epoch 00020: val_loss did not improve from 0.10274
# Epoch 21/50
#  - 70s - loss: 0.0760 - accuracy: 0.9748 - val_loss: 0.1155 - val_accuracy: 0.9622
#
# Epoch 00021: val_loss did not improve from 0.10274
# Epoch 22/50
#  - 69s - loss: 0.0743 - accuracy: 0.9762 - val_loss: 0.9139 - val_accuracy: 0.7914
#
# Epoch 00022: val_loss did not improve from 0.10274
# Epoch 23/50
#  - 70s - loss: 0.0741 - accuracy: 0.9781 - val_loss: 0.1966 - val_accuracy: 0.9431
#
# Epoch 00023: val_loss did not improve from 0.10274
# Epoch 24/50
#  - 70s - loss: 0.0749 - accuracy: 0.9757 - val_loss: 0.1659 - val_accuracy: 0.9511
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00024: val_loss did not improve from 0.10274
# Epoch 25/50
#  - 70s - loss: 0.0691 - accuracy: 0.9790 - val_loss: 0.2633 - val_accuracy: 0.9382
#
# Epoch 00025: val_loss did not improve from 0.10274
# Epoch 26/50
#  - 70s - loss: 0.0699 - accuracy: 0.9773 - val_loss: 0.1600 - val_accuracy: 0.9566
#
# Epoch 00026: val_loss did not improve from 0.10274
# Epoch 27/50
#  - 70s - loss: 0.0685 - accuracy: 0.9781 - val_loss: 0.5050 - val_accuracy: 0.8888
#
# Epoch 00027: val_loss did not improve from 0.10274
# Epoch 28/50
#  - 70s - loss: 0.0623 - accuracy: 0.9808 - val_loss: 0.4277 - val_accuracy: 0.8939
#
# Epoch 00028: val_loss did not improve from 0.10274
# Epoch 29/50
#  - 70s - loss: 0.0605 - accuracy: 0.9807 - val_loss: 0.3900 - val_accuracy: 0.9121
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00029: val_loss did not improve from 0.10274
# Epoch 30/50
#  - 69s - loss: 0.0588 - accuracy: 0.9816 - val_loss: 0.2783 - val_accuracy: 0.9273
#
# Epoch 00030: val_loss did not improve from 0.10274
# Epoch 31/50
#  - 70s - loss: 0.0579 - accuracy: 0.9809 - val_loss: 0.1220 - val_accuracy: 0.9625
#
# Epoch 00031: val_loss did not improve from 0.10274
# Epoch 32/50
#  - 71s - loss: 0.0572 - accuracy: 0.9819 - val_loss: 0.4303 - val_accuracy: 0.8961
#
# Epoch 00032: val_loss did not improve from 0.10274
# Epoch 33/50
#  - 71s - loss: 0.0525 - accuracy: 0.9840 - val_loss: 0.1176 - val_accuracy: 0.9634
#
# Epoch 00033: val_loss did not improve from 0.10274
# Epoch 34/50
#  - 70s - loss: 0.0510 - accuracy: 0.9828 - val_loss: 0.1249 - val_accuracy: 0.9620
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00034: val_loss did not improve from 0.10274
# Epoch 35/50
#  - 71s - loss: 0.0536 - accuracy: 0.9826 - val_loss: 0.1623 - val_accuracy: 0.9523
#
# Epoch 00035: val_loss did not improve from 0.10274
# Epoch 36/50
#  - 70s - loss: 0.0512 - accuracy: 0.9830 - val_loss: 0.0452 - val_accuracy: 0.9852
#
# Epoch 00036: val_loss improved from 0.10274 to 0.04520, saving model to model.h5
# Epoch 37/50
#  - 69s - loss: 0.0508 - accuracy: 0.9847 - val_loss: 0.7568 - val_accuracy: 0.8375
#
# Epoch 00037: val_loss did not improve from 0.04520
# Epoch 38/50
#  - 70s - loss: 0.0440 - accuracy: 0.9857 - val_loss: 0.1741 - val_accuracy: 0.9574
#
# Epoch 00038: val_loss did not improve from 0.04520
# Epoch 39/50
#  - 70s - loss: 0.0478 - accuracy: 0.9847 - val_loss: 0.3560 - val_accuracy: 0.9159
#
# Epoch 00039: val_loss did not improve from 0.04520
# Epoch 40/50
#  - 70s - loss: 0.0518 - accuracy: 0.9843 - val_loss: 0.1073 - val_accuracy: 0.9658
#
# Epoch 00040: val_loss did not improve from 0.04520
# Epoch 41/50
#  - 71s - loss: 0.0463 - accuracy: 0.9850 - val_loss: 0.7407 - val_accuracy: 0.8505
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00041: val_loss did not improve from 0.04520
# Epoch 42/50
#  - 71s - loss: 0.0436 - accuracy: 0.9859 - val_loss: 0.2231 - val_accuracy: 0.9421
#
# Epoch 00042: val_loss did not improve from 0.04520
# Epoch 43/50
#  - 70s - loss: 0.0412 - accuracy: 0.9878 - val_loss: 0.2186 - val_accuracy: 0.9404
#
# Epoch 00043: val_loss did not improve from 0.04520
# Epoch 44/50
#  - 70s - loss: 0.0382 - accuracy: 0.9880 - val_loss: 0.5676 - val_accuracy: 0.8857
#
# Epoch 00044: val_loss did not improve from 0.04520
# Epoch 45/50
#  - 70s - loss: 0.0453 - accuracy: 0.9852 - val_loss: 0.1560 - val_accuracy: 0.9571
#
# Epoch 00045: val_loss did not improve from 0.04520
# Epoch 46/50
#  - 70s - loss: 0.0386 - accuracy: 0.9880 - val_loss: 0.1854 - val_accuracy: 0.9469
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00046: val_loss did not improve from 0.04520
# Epoch 47/50
#  - 70s - loss: 0.0458 - accuracy: 0.9872 - val_loss: 0.6349 - val_accuracy: 0.8622
#
# Epoch 00047: val_loss did not improve from 0.04520
# Epoch 48/50
#  - 70s - loss: 0.0376 - accuracy: 0.9891 - val_loss: 0.1624 - val_accuracy: 0.9554
#
# Epoch 00048: val_loss did not improve from 0.04520
# Epoch 49/50
#  - 70s - loss: 0.0364 - accuracy: 0.9878 - val_loss: 0.3221 - val_accuracy: 0.9271
#
# Epoch 00049: val_loss did not improve from 0.04520
# Epoch 50/50
#  - 71s - loss: 0.0378 - accuracy: 0.9888 - val_loss: 0.0906 - val_accuracy: 0.9738
#
# Epoch 00050: val_loss did not improve from 0.04520

# %%
#model = load_model('../output/kaggle/working/model.h5')
final_loss, final_accuracy = model.evaluate(X_val, Y_val)
print('Final Loss: {}, Final Accuracy: {}'.format(final_loss, final_accuracy))
# Out:
# 4128/4128 [==============================] - 5s 1ms/step
# Final Loss: 0.09057462476365369, Final Accuracy: 0.9738371968269348

# %%
Y_pred = model.predict(X_val)

Y_pred = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_val, axis=1)

cm = confusion_matrix(Y_true, Y_pred)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap=plt.cm.Greens, annot=True, square=True, xticklabels=disease_types, yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=40)
ax.set_xlabel('Predicted', fontsize=40)
# Out:
# Text(0.5, 144.41374999999996, 'Predicted')

# %%
# accuracy plot 
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# loss plot
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # Testing Disease Prediction

# %%
from skimage import io
from keras.preprocessing import image
#path='imbalanced/Scratch/Scratch_400.jpg'
img = image.load_img('../input/plantdisease/PlantVillage/Potato___Early_blight/042135e2-e126-4900-9212-d42d900b8125___RS_Early.B 8791.JPG', grayscale=False, target_size=(64, 64))
show_img=image.load_img('../input/plantdisease/PlantVillage/Potato___Early_blight/042135e2-e126-4900-9212-d42d900b8125___RS_Early.B 8791.JPG', grayscale=False, target_size=(200, 200))
disease_class = ['Pepper__bell___Bacterial_spot','Pepper__bell___healthy','Potato___Early_blight','Potato___Late_blight','Potato___healthy','Tomato_Bacterial_spot','Tomato_Early_blight','Tomato_Late_blight','Tomato_Leaf_Mold','Tomato_Septoria_leaf_spot','Tomato_Spider_mites_Two_spotted_spider_mite','Tomato__Target_Spot','Tomato__Tomato_YellowLeaf__Curl_Virus','Tomato__Tomato_mosaic_virus','Tomato_healthy']
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
#x = np.array(x, 'float32')
x /= 255

custom = model.predict(x)
print(custom[0])



#x = x.reshape([64, 64]);

#plt.gray()
plt.imshow(show_img)
plt.show()

a=custom[0]
ind=np.argmax(a)
        
print('Prediction:',disease_class[ind])
# Out:
# [4.2683372e-04 9.6306689e-03 4.3890873e-01 1.8698012e-04 4.4792923e-03
#  1.1440736e-06 5.3031892e-01 1.6436167e-04 2.4966086e-05 1.4613056e-02
#  5.7137140e-07 7.8904586e-06 3.0799230e-05 5.1678118e-04 6.8902120e-04]
# Prediction: Tomato_Early_blight

# %% [markdown]
# - -
